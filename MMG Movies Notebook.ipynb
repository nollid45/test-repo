# %%
# The code was removed by Watson Studio for sharing.
# Out:
# [Row(movieId='1', title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy', userId='124', rating='4.5', timestamp.x='1147862310', tag=None, timestamp.y=None),
#  Row(movieId='1', title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy', userId='125', rating='4.0', timestamp.x='1269736592', tag=None, timestamp.y=None),
#  Row(movieId='1', title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy', userId='13', rating='5.0', timestamp.x='1331380058', tag=None, timestamp.y=None),
#  Row(movieId='1', title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy', userId='138', rating='2.0', timestamp.x='1440379001', tag=None, timestamp.y=None),
#  Row(movieId='1', title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy', userId='146', rating='5.0', timestamp.x='1256071139', tag=None, timestamp.y=None),
# ...
